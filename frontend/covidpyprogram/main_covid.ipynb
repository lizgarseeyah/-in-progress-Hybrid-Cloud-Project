# %%
# Data Source Site: https://ourworldindata.org/coronavirus-source-data
# Data Source GitHub: https://github.com/owid/covid-19-data/tree/master/public/data
print ("Action Required: Find raw stock market data")
# Out:
# Action Required: Find raw stock market data

# %%
# This program analyzes Covid Data and its impact on the economy

# The user will be able to control a time scale, enable features, and queries 
# important events. The program should also be able to predict what stocks are doing 
# well?

# %%
# source: https://realpython.com/python-web-scraping-practical-introduction/#use-an-html-parser-for-web-scraping-in-python
# import statements
from bs4 import BeautifulSoup
from urllib.request import urlopen
import time, os
import urllib
import requests
import pandas as pd
import numpy as np
import csv
import re


# Part 1: import data
    
# define url
url = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'

# csv file repo
file = '/Users/lizgarcia/Desktop/ROADMAP/AWS-Azure/CloudMigrationProject/source/covid_data.csv'

# check connection
response = requests.get(url)
if response.status_code != 200:
    print("Error fetching page")
    exit()
else:
    content = response.content
    print(content)

soup = BeautifulSoup(response.content, 'lxml')

# read from web source and write to overwrite to csv file on local storage
df = pd.read_csv(url)
df.to_csv(file)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.read_csv(file, index_col=0)
df
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  2019-12-31          0.0        0.0
# 1          AFG      Asia    Afghanistan  2020-01-01          0.0        0.0
# 2          AFG      Asia    Afghanistan  2020-01-02          0.0        0.0
# 3          AFG      Asia    Afghanistan  2020-01-03          0.0        0.0
# 4          AFG      Asia    Afghanistan  2020-01-04          0.0        0.0
# ...        ...       ...            ...         ...          ...        ...
# 45634      NaN       NaN  International  2020-09-19        696.0        NaN
# 45635      NaN       NaN  International  2020-09-20        696.0        NaN
# 45636      NaN       NaN  International  2020-09-21        696.0        NaN
# 45637      NaN       NaN  International  2020-09-22        696.0        NaN
# 45638      NaN       NaN  International  2020-09-23        696.0        NaN
#
# ...
